# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(42)

n = 100

df = pd.DataFrame({
    'employee_id': [f'E{str(i).zfill(3)}' for i in range(1, n+1)],
    'department': np.random.choice(['HR', 'Sales', 'IT', 'Finance', 'Operations'], n),
    'age': np.random.randint(22, 50, n),
    'experience_years': np.random.randint(1, 20, n),
    'satisfaction_score': np.random.randint(3, 10, n),
    'attendance_percent': np.random.randint(65, 100, n),
    'overtime_hours': np.random.randint(0, 25, n),
    'performance_rating': np.random.randint(1, 6, n)
})

df.head()
# Out:
#   employee_id  department  age  experience_years  satisfaction_score  \
# 0        E001     Finance   49                17                   8
# 1        E002  Operations   28                12                   7
# 2        E003          IT   30                 7                   5
# 3        E004  Operations   29                 2                   8
# 4        E005  Operations   33                 3                   5
#
#    attendance_percent  overtime_hours  performance_rating
# 0                  89              23                   1
# 1                  86               3                   5
# 2                  86              24                   4
# 3                  70              20                   4
# 4                  79              24                   4

# %%
def classify_risk(row):
    if row['satisfaction_score'] < 5 and row['overtime_hours'] > 15:
        return 'High Risk'
    elif row['satisfaction_score'] < 6 or row['attendance_percent'] < 75:
        return 'Medium Risk'
    else:
        return 'Low Risk'

df['risk_level'] = df.apply(classify_risk, axis=1)

df[['employee_id','satisfaction_score','overtime_hours','attendance_percent','risk_level']].head()
# Out:
#   employee_id  satisfaction_score  overtime_hours  attendance_percent  \
# 0        E001                   8              23                  89
# 1        E002                   7               3                  86
# 2        E003                   5              24                  86
# 3        E004                   8              20                  70
# 4        E005                   5              24                  79
#
#     risk_level
# 0     Low Risk
# 1     Low Risk
# 2  Medium Risk
# 3  Medium Risk
# 4  Medium Risk

# %%
def recommend_action(row):
    if row['risk_level'] == 'High Risk':
        return 'Immediate HR intervention'
    elif row['risk_level'] == 'Medium Risk':
        return 'Monitor and training'
    else:
        return 'Maintain performance'

df['recommended_action'] = df.apply(recommend_action, axis=1)

df[['employee_id','risk_level','recommended_action']].head()
# Out:
#   employee_id   risk_level    recommended_action
# 0        E001     Low Risk  Maintain performance
# 1        E002     Low Risk  Maintain performance
# 2        E003  Medium Risk  Monitor and training
# 3        E004  Medium Risk  Monitor and training
# 4        E005  Medium Risk  Monitor and training

# %%
df['risk_level'].value_counts()
# Out:
# risk_level
# Medium Risk    53
# Low Risk       39
# High Risk       8
# Name: count, dtype: int64

# %%
df.groupby(['department','risk_level']).size().unstack(fill_value=0)
# Out:
# risk_level  High Risk  Low Risk  Medium Risk
# department
# Finance             1        13           12
# HR                  2         7            9
# IT                  1         6            9
# Operations          2         6           11
# Sales               2         7           12

# %%
df[df['risk_level'] == 'High Risk']
# Out:
#    employee_id  department  age  experience_years  satisfaction_score  \
# 9         E010  Operations   44                17                   3
# 19        E020     Finance   24                 4                   3
# 30        E031          IT   48                 9                   3
# 33        E034          HR   36                 3                   3
# 47        E048  Operations   36                18                   4
# 55        E056          HR   49                 1                   4
# 59        E060       Sales   46                 5                   4
# 64        E065       Sales   33                16                   4
#
#     attendance_percent  overtime_hours  performance_rating risk_level  \
# 9                   70              23                   2  High Risk
# 19                  92              22                   4  High Risk
# 30                  65              16                   1  High Risk
# 33                  86              24                   4  High Risk
# 47                  80              18                   2  High Risk
# 55                  69              19                   4  High Risk
# 59                  83              22                   5  High Risk
# 64                  80              20                   2  High Risk
#
#            recommended_action
# 9   Immediate HR intervention
# 19  Immediate HR intervention
# 30  Immediate HR intervention
# 33  Immediate HR intervention
# 47  Immediate HR intervention
# 55  Immediate HR intervention
# 59  Immediate HR intervention
# 64  Immediate HR intervention

# %%
print("Insights:")
print("High risk employees need immediate attention")
print("Low satisfaction + high overtime = major issue")
print("Departments with more risk need HR focus")
# Out:
# Insights:
# High risk employees need immediate attention
# Low satisfaction + high overtime = major issue
# Departments with more risk need HR focus

# %%
df.to_csv("DSS_Output.csv", index=False)

from google.colab import files
files.download("DSS_Output.csv")
